# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1, 3, 2,4])
plt.show()

# %%
plt.plot([1, 2, 3,4], [1, 4, 9,16])
plt.title('Test Plot')
plot.xlabel('number n')
plot.ylabel('n^2')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-29d472c066c0> in <cell line: 3>()
#       1 plt.plot([1, 2, 3,4], [1, 4, 9,16])
#       2 plt.title('Test Plot')
# ----> 3 plot.xlabel('number n')
#       4 plot.ylabel('n^2')
#       5 plt.show()
#
# NameError: name 'plot' is not defined

# %%
plt.figure(figsize=(2,5))  #2 inches wide x 5 inches tall
plt.plot([1, 2, 3, 4], [1, 4, 9,16], 'kx')
plt.axis([0, 6, 0, 20])
plt.annotate('square it', (3,6))
plt.show()

# %%
plt.clf()
x = np.arange(4)
y = [8.8, 5.2, 3.6, 5.9]
plt.xticks(x, ('Ankit', 'Hans', 'Joe', 'Flaco'))
plt.bar(x, y, color='y')
plt.show()

# %%
d = {'Red O' : np.random.rand(10),
    'Grn X'  : np.random.rand(10)}
df = pd.DataFrame(d)
df.plot(style=['ro','gx'])
plt.show()

# %%
ts = pd.Series(np.random.randn(180), index=pd.date_range('1/1/2018',periods = 180))
df = pd.DataFrame(np.random.randn(180, 3), index=ts.index, columns=list('ABC'))
df.cumsum().plot()
plt.show()

# %%
Time Series - six months of random np.FLOATING_POINT_SUPPORT

# %% [markdown]
# [link text](https://)

# %%
#Random dots in a scatter

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sizes = (30 * np.random.rand(N))**2  #0 to 15 radii
plt.scatter(x, y, s=sizes, c=colors, alpha=0.5)
plt.show()
